# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#EDA
df_mawlynnong = pd.read_csv('../data/Mawlynnong.csv')
df_delhi = pd.read_csv('../data/Delhi.csv')
df_chennai = pd.read_csv('../data/Chennai.csv')
df_Koonimedu = pd.read_csv('../data/Koonimedu.csv')

# %%
df_delhi['City'] = 'Delhi'
df_mawlynnong['City'] = 'Mawlynnong'
df_chennai['City'] = 'Chennai'
df_Koonimedu['City'] = 'Koonimedu'

# %%
df_chennai.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00          21.7           14.6                      305
# 1  2022-09-01T01:00          21.0           14.3                      291
# 2  2022-09-01T02:00          19.0           13.0                      272
# 3  2022-09-01T03:00          15.8           10.7                      245
# 4  2022-09-01T04:00          14.4            9.7                      227
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)     City
# 0                      25.4                     30.6             12  Chennai
# 1                      23.1                     30.0             15  Chennai
# 2                      19.9                     29.1             20  Chennai
# 3                      15.9                     27.8             25  Chennai
# 4                      13.9                     26.9             28  Chennai

# %%
df_Koonimedu.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00          26.8           18.2                      209
# 1  2022-09-01T01:00          27.3           18.6                      206
# 2  2022-09-01T02:00          26.0           17.7                      201
# 3  2022-09-01T03:00          23.9           16.2                      191
# 4  2022-09-01T04:00          21.7           14.6                      177
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)       City
# 0                      41.3                     57.7             11  Koonimedu
# 1                      36.5                     54.3             15  Koonimedu
# 2                      29.6                     49.6             20  Koonimedu
# 3                      21.1                     41.3             27  Koonimedu
# 4                      16.5                     32.7             31  Koonimedu

# %%
df_delhi.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00         108.5           68.9                     1220
# 1  2022-09-01T01:00          89.4           55.9                     1117
# 2  2022-09-01T02:00          82.9           51.9                      970
# 3  2022-09-01T03:00          72.4           41.8                      768
# 4  2022-09-01T04:00          68.0           36.9                      622
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)   City
# 0                      64.2                     37.0              3  Delhi
# 1                      59.5                     33.7             11  Delhi
# 2                      52.8                     28.9             22  Delhi
# 3                      42.7                     23.8             43  Delhi
# 4                      33.8                     22.8             67  Delhi

# %%
df_mawlynnong.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00          19.3           13.4                      219
# 1  2022-09-01T01:00          16.2           11.3                      212
# 2  2022-09-01T02:00          13.2            9.2                      201
# 3  2022-09-01T03:00          12.8            8.8                      188
# 4  2022-09-01T04:00          13.2            9.1                      180
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                       2.2                      1.5             75
# 1                       2.2                      1.6             75
# 2                       2.3                      1.8             74
# 3                       2.2                      1.9             75
# 4                       2.0                      1.6             77
#
#          City
# 0  Mawlynnong
# 1  Mawlynnong
# 2  Mawlynnong
# 3  Mawlynnong
# 4  Mawlynnong

# %%
print(df_mawlynnong.info())
print(df_delhi.info())
print(df_chennai.info())
print(df_Koonimedu.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21216 entries, 0 to 21215
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   time                      21216 non-null  object
#  1   pm10 (μg/m³)              21216 non-null  float64
#  2   pm2_5 (μg/m³)             21216 non-null  float64
#  3   carbon_monoxide (μg/m³)   21216 non-null  int64
#  4   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  5   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  6   ozone (μg/m³)             21216 non-null  int64
#  7   City                      21216 non-null  object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21216 entries, 0 to 21215
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
# ...

# %%
print(df_chennai.describe())
print(df_delhi.describe())
print(df_mawlynnong.describe())
print(df_Koonimedu.describe())
# Out:
#        pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# count  21216.000000   21216.000000              21216.00000
# mean      38.776122      24.016247                271.73685
# std       20.791958      13.176516                107.74514
# min        0.700000       0.500000                 59.00000
# 25%       23.800000      14.400000                205.00000
# 50%       35.400000      21.500000                251.00000
# 75%       49.700000      31.300000                316.00000
# max      194.200000     133.600000               1956.00000
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# count              21216.000000             21216.000000   21216.000000
# mean                  11.879643                13.118133      81.276254
# std                   10.443430                11.831789      33.754375
# min                    0.000000                 0.200000       0.000000
# ...

# %%
print(df_chennai.isnull().sum())
print(df_delhi.isnull().sum())
print(df_mawlynnong.isnull().sum())
print(df_Koonimedu.isnull().sum())
# Out:
# time                        0
# pm10 (μg/m³)                0
# pm2_5 (μg/m³)               0
# carbon_monoxide (μg/m³)     0
# nitrogen_dioxide (μg/m³)    0
# sulphur_dioxide (μg/m³)     0
# ozone (μg/m³)               0
# City                        0
# dtype: int64
# time                        0
# pm10 (μg/m³)                0
# pm2_5 (μg/m³)               0
# carbon_monoxide (μg/m³)     0
# nitrogen_dioxide (μg/m³)    0
# sulphur_dioxide (μg/m³)     0
# ozone (μg/m³)               0
# City                        0
# dtype: int64
# time                        0
# pm10 (μg/m³)                0
# pm2_5 (μg/m³)               0
# carbon_monoxide (μg/m³)     0
# nitrogen_dioxide (μg/m³)    0
# sulphur_dioxide (μg/m³)     0
# ozone (μg/m³)               0
# City                        0
# dtype: int64
# time                        0
# pm10 (μg/m³)                0
# pm2_5 (μg/m³)               0
# carbon_monoxide (μg/m³)     0
# nitrogen_dioxide (μg/m³)    0
# ...

# %%
# Convert 'time' column to datetime if applicable
df_chennai['time'] = pd.to_datetime(df_chennai['time'], errors='coerce')
df_delhi['time'] = pd.to_datetime(df_delhi['time'], errors='coerce')
df_mawlynnong['time'] = pd.to_datetime(df_mawlynnong['time'], errors='coerce')
df_Koonimedu['time'] = pd.to_datetime(df_Koonimedu['time'], errors='coerce')

# %%
# Handling missing values (optional: fill or drop)
#df = df.dropna()  # Drops rows with missing values
# df.fillna(df.mean(), inplace=True)  # Alternative: Fill with mean values

#no missing values in the dataset

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_mawlynnong.drop(columns=['City']).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_Koonimedu.drop(columns=['City']).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_delhi.drop(columns=['City']).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_chennai.drop(columns=['City']).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Distribution of numerical columns for Chennai
df_chennai.drop(columns=['time']).hist(figsize=(12, 8), bins=20)
plt.suptitle("Feature Distributions - Chennai")
plt.show()

# %%
# Distribution of numerical columns for Koonimedu
df_Koonimedu.drop(columns=['time']).hist(figsize=(12, 8), bins=20)
plt.suptitle("Feature Distributions - Koonimedu")
plt.show()

# %%
# Distribution of numerical columns for Delhi
df_delhi.drop(columns=['time']).hist(figsize=(12, 8), bins=20)
plt.suptitle("Feature Distributions - Delhi")
plt.show()

# %%
# Distribution of numerical columns for Mawlynnong
df_mawlynnong.drop(columns=['time']).hist(figsize=(12, 8), bins=20)
plt.suptitle("Feature Distributions - Mawlynnong")
plt.show()

# %%
# Boxplot to identify outliers for Chennai
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_chennai.drop(columns=['time', 'City']))
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection - Chennai")
plt.show()

# %%
# Boxplot to identify outliers for Mawlynnong
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_mawlynnong.drop(columns=['time', 'City']))
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection - Mawlynnong")
plt.show()

# %%
# Boxplot to identify outliers for Delhi
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_delhi.drop(columns=['time', 'City']))
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection - Delhi")
plt.show()

# %%
# Boxplot to identify outliers for Koonimedu
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_Koonimedu.drop(columns=['time', 'City']))
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection - Koonimedu")
plt.show()

# %%
# Time series trend analysis for Chennai
plt.figure(figsize=(12, 6))
for col in df_chennai.columns[1:-1]:  # Skipping 'time' and 'City' columns
    plt.plot(df_chennai['time'], df_chennai[col], label=col)
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.title("Time Series Trends - Chennai")
plt.show()

# %%
# Time series trend analysis for Mawlynnong
plt.figure(figsize=(12, 6))
for col in df_mawlynnong.columns[1:-1]:  # Skipping 'time' and 'City' columns
    plt.plot(df_mawlynnong['time'], df_mawlynnong[col], label=col)
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.title("Time Series Trends - Mawlynnong")
plt.show()

# %%
# Time series trend analysis for Delhi
plt.figure(figsize=(12, 6))
for col in df_delhi.columns[1:-1]:  # Skipping 'time' and 'City' columns
    plt.plot(df_delhi['time'], df_delhi[col], label=col)
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.title("Time Series Trends - Delhi")
plt.show()

# %%
# Time series trend analysis for Koonimedu
plt.figure(figsize=(12, 6))
for col in df_Koonimedu.columns[1:-1]:  # Skipping 'time' and 'City' columns
    plt.plot(df_Koonimedu['time'], df_Koonimedu[col], label=col)
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.title("Time Series Trends - Koonimedu")
plt.show()
