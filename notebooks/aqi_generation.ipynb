# %%
import os
import pandas as pd
import numpy as np
import sub_index
# import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = "../data/cleaneddata/"
output_dir = "../data/AQIdata/"
os.makedirs(output_dir, exist_ok=True)

# %%
stations = ["Chennai", "Delhi", "Koonimedu","Mawlynnong"]

# %%
from sub_index import get_PM25_subindex, get_PM10_subindex, get_CO_subindex, get_O3_subindex, get_SO2_subindex, get_NOx_subindex

# %%
# Function to calculate hourly AQI
def calculate_hourly_aqi(df):
    sub_indices = {
        "pm2_5 (μg/m³)": get_PM25_subindex,
        "pm10 (μg/m³)": get_PM10_subindex,
        "carbon_monoxide (μg/m³)": get_CO_subindex,
        "ozone (μg/m³)": get_O3_subindex,
        "sulphur_dioxide (μg/m³)": get_SO2_subindex,
        "nitrogen_dioxide (μg/m³)": get_NOx_subindex
    }
    
    # Convert pollutants to numeric (force errors to NaN)
    for col in sub_indices.keys():
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Compute sub-indices
    for pollutant, func in sub_indices.items():
        if pollutant in df.columns:
            df[f"{pollutant}_subindex"] = df[pollutant].apply(lambda x: func(x) if pd.notna(x) else None)

    # Compute AQI using the highest subindex
    df["AQI"] = df[[col for col in df.columns if "subindex" in col]].max(axis=1)

    print(df.head())  # Debugging: Print first few rows to check calculations

    return df

# %%
# Function to calculate daily AQI using 24-hour rolling averages
def calculate_daily_aqi(df):
    # Resample to daily level and calculate mean for each day
    df_daily = df.set_index('time').resample('D').mean().reset_index()
    
    return calculate_hourly_aqi(df_daily)

# %%
# Process each station CSV
for station in stations:
    input_file = os.path.join(data_dir, f"{station}.csv")

    if os.path.exists(input_file):
        df = pd.read_csv(input_file, parse_dates=["time"])  # Ensure 'time' column is datetime
        df.sort_values(by="time", inplace=True)  # Sort time-series data

        # Debugging: Print first few rows to check if data is loaded properly
        print(f"Processing {station} - First few rows:")
        print(df.head())

        # Hourly AQI Calculation
        hourly_aqi_df = calculate_hourly_aqi(df.copy())
        hourly_aqi_df.to_csv(os.path.join(output_dir, f"{station}_hourly_AQI.csv"), index=False)

        # Daily AQI Calculation
        daily_aqi_df = calculate_daily_aqi(df.copy())
        daily_aqi_df.rename(columns={"time": "date"}, inplace=True)
        daily_aqi_df.to_csv(os.path.join(output_dir, f"{station}_daily_AQI.csv"), index=False)

        print(f"AQI computed and saved for {station}")
    else:
        print(f"Data file for {station} not found!")
# Out:
# Processing Chennai - First few rows:
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     21.691429      14.634286               303.028571
# 1 2022-09-01 01:00:00     20.940000      14.240000               292.028571
# 2 2022-09-01 02:00:00     18.751429      12.802857               270.285714
# 3 2022-09-01 03:00:00     15.928571      10.820000               247.228571
# 4 2022-09-01 04:00:00     14.751429       9.914286               226.571429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 25.082857                30.522857      12.342857
# 1                 23.211429                30.034286      15.085714
# 2                 19.668571                29.022857      20.000000
# 3                 16.268571                27.911429      24.742857
# 4                 13.840000                26.925714      27.914286
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     21.691429      14.634286               303.028571
# 1 2022-09-01 01:00:00     20.940000      14.240000               292.028571
# 2 2022-09-01 02:00:00     18.751429      12.802857               270.285714
# 3 2022-09-01 03:00:00     15.928571      10.820000               247.228571
# 4 2022-09-01 04:00:00     14.751429       9.914286               226.571429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                 25.082857                30.522857      12.342857
# 1                 23.211429                30.034286      15.085714
# 2                 19.668571                29.022857      20.000000
# 3                 16.268571                27.911429      24.742857
# 4                 13.840000                26.925714      27.914286
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      24                     22
# 1                      24                     21
# 2                      21                     19
# 3                      18                     16
# 4                      17                     15
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                15                      12
# 1                                15                      15
# 2                                14                      20
# 3                                12                      25
# 4                                11                      28
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                38                                 31   38
# 1                                38                                 29   38
# 2                                36                                 25   36
# 3                                35                                 20   35
# 4                                34                                 17   34
#         time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01     16.975595      11.324881               260.960714
# 1 2022-09-02     23.900833      14.851786               216.500000
# 2 2022-09-03     45.785000      29.625714               266.538095
# 3 2022-09-04     42.779048      28.211429               294.498810
# 4 2022-09-05     37.715714      24.764286               272.763095
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                 14.001310                24.433571      27.367857
# 1                 15.180238                16.973690      49.507143
# 2                 21.304643                22.163333      82.386905
# 3                 21.417738                22.800397      92.986905
# 4                 21.513929                24.431746      86.973810
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      19                     17
# 1                      25                     24
# 2                      49                     46
# 3                      47                     43
# 4                      41                     38
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                13                      27
# 1                                11                      50
# 2                                13                      82
# 3                                15                      93
# 4                                14                      87
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                31                                 18   31
# 1                                21                                 19   50
# 2                                28                                 27   82
# 3                                29                                 27   93
# 4                                31                                 27   87
# AQI computed and saved for Chennai
# Processing Delhi - First few rows:
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00    104.145714      65.900000              1206.114286
# 1 2022-09-01 01:00:00     93.540000      59.080000              1123.000000
# 2 2022-09-01 02:00:00     80.611429      49.637143               959.542857
# 3 2022-09-01 03:00:00     73.788571      43.137143               782.571429
# 4 2022-09-01 04:00:00     67.220000      36.428571               616.771429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 63.565714                36.562857       4.114286
# 1                 59.851429                33.751429       9.971429
# 2                 52.285714                28.625714      23.200000
# 3                 43.274286                24.425714      42.142857
# 4                 33.542857                22.671429      67.771429
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00    104.145714      65.900000              1206.114286
# 1 2022-09-01 01:00:00     93.540000      59.080000              1123.000000
# 2 2022-09-01 02:00:00     80.611429      49.637143               959.542857
# 3 2022-09-01 03:00:00     73.788571      43.137143               782.571429
# 4 2022-09-01 04:00:00     67.220000      36.428571               616.771429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                 63.565714                36.562857       4.114286
# 1                 59.851429                33.751429       9.971429
# 2                 52.285714                28.625714      23.200000
# 3                 43.274286                24.425714      42.142857
# 4                 33.542857                22.671429      67.771429
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                     120                    103
# 1                      98                     94
# 2                      83                     81
# 3                      72                     74
# 4                      61                     67
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                60                       4
# 1                                56                      10
# 2                                48                      23
# 3                                39                      42
# 4                                31                      68
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                46                                 79  120
# 1                                42                                 75   98
# 2                                36                                 65   83
# 3                                31                                 54   74
# 4                                28                                 42   68
#         time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01    112.961429      67.476190               849.997619
# 1 2022-09-02    104.800238      64.586429              1258.309921
# 2 2022-09-03     80.548333      45.851310              1171.232143
# 3 2022-09-04     60.251071      31.261310               758.261905
# 4 2022-09-05    119.378849      66.334484              1139.228571
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                 43.923690                46.812222      57.227381
# 1                 49.092381                60.137024      61.308333
# 2                 42.969762                37.232738      47.777381
# 3                 44.033214                23.157262      46.004762
# 4                 55.173452                49.042897      51.741667
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                     125                    109
# 1                     115                    103
# 2                      76                     81
# 3                      52                     60
# 4                     121                    113
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                42                      57
# 1                                63                      61
# 2                                59                      48
# 3                                38                      46
# 4                                57                      52
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                59                                 55  125
# 1                                75                                 61  115
# 2                                47                                 54   81
# 3                                29                                 55   60
# 4                                61                                 69  121
# AQI computed and saved for Delhi
# Processing Koonimedu - First few rows:
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     27.040000      18.380000               208.657143
# 1 2022-09-01 01:00:00     27.017143      18.394286               206.342857
# 2 2022-09-01 02:00:00     26.025714      17.717143               200.657143
# 3 2022-09-01 03:00:00     23.960000      16.242857               191.000000
# 4 2022-09-01 04:00:00     21.588571      14.522857               177.000000
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 12.143810                19.897143      11.600000
# 1                 12.382857                19.112381      14.657143
# 2                 11.256190                16.813333      20.514286
# 3                 12.682857                16.433333      26.228571
# 4                 14.131429                19.480000      31.514286
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     27.040000      18.380000               208.657143
# 1 2022-09-01 01:00:00     27.017143      18.394286               206.342857
# 2 2022-09-01 02:00:00     26.025714      17.717143               200.657143
# 3 2022-09-01 03:00:00     23.960000      16.242857               191.000000
# 4 2022-09-01 04:00:00     21.588571      14.522857               177.000000
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                 12.143810                19.897143      11.600000
# 1                 12.382857                19.112381      14.657143
# 2                 11.256190                16.813333      20.514286
# 3                 12.682857                16.433333      26.228571
# 4                 14.131429                19.480000      31.514286
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      31                     27
# 1                      31                     27
# 2                      30                     26
# 3                      27                     24
# 4                      24                     22
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                10                      12
# 1                                10                      15
# 2                                10                      21
# 3                                10                      26
# 4                                 9                      32
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                25                                 15   31
# 1                                24                                 15   31
# 2                                21                                 14   30
# 3                                21                                 16   27
# 4                                24                                 18   32
#         time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01     18.082500      12.075238               154.228571
# 1 2022-09-02     26.674167      17.524881               181.205952
# 2 2022-09-03     37.828929      25.569881               212.432143
# 3 2022-09-04     32.168690      21.504881               189.284524
# 4 2022-09-05     31.458571      21.084167               195.465476
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                  9.534286                11.442381      33.236905
# 1                  6.185397                10.427262      66.379762
# 2                  9.791151                15.714683      78.516667
# 3                  7.294365                13.818452      92.454762
# 4                  8.345714                17.350913      87.290476
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      20                     18
# 1                      29                     27
# 2                      43                     38
# 3                      36                     32
# 4                      35                     31
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                 8                      33
# 1                                 9                      66
# 2                                11                      79
# 3                                 9                      92
# 4                                10                      87
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                14                                 12   33
# 1                                13                                  8   66
# 2                                20                                 12   79
# 3                                17                                  9   92
# 4                                22                                 10   87
# AQI computed and saved for Koonimedu
# Processing Mawlynnong - First few rows:
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     18.760000      13.040000               218.142857
# 1 2022-09-01 01:00:00     16.260000      11.334286               212.085714
# 2 2022-09-01 02:00:00     13.568571       9.431429               200.571429
# 3 2022-09-01 03:00:00     12.757143       8.800000               188.942857
# 4 2022-09-01 04:00:00     13.080000       9.014286               179.485714
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                  2.191429                 1.508571      75.085714
# 1                  2.234286                 1.617143      74.657143
# 2                  2.265714                 1.808571      74.342857
# 3                  2.208571                 1.848571      75.000000
# 4                  1.982857                 1.608571      76.828571
#                  time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01 00:00:00     18.760000      13.040000               218.142857
# 1 2022-09-01 01:00:00     16.260000      11.334286               212.085714
# 2 2022-09-01 02:00:00     13.568571       9.431429               200.571429
# 3 2022-09-01 03:00:00     12.757143       8.800000               188.942857
# 4 2022-09-01 04:00:00     13.080000       9.014286               179.485714
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                  2.191429                 1.508571      75.085714
# 1                  2.234286                 1.617143      74.657143
# 2                  2.265714                 1.808571      74.342857
# 3                  2.208571                 1.848571      75.000000
# 4                  1.982857                 1.608571      76.828571
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      22                     19
# 1                      19                     16
# 2                      16                     14
# 3                      15                     13
# 4                      15                     13
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                11                      75
# 1                                11                      75
# 2                                10                      74
# 3                                 9                      75
# 4                                 9                      77
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                 2                                  3   75
# 1                                 2                                  3   75
# 2                                 2                                  3   74
# 3                                 2                                  3   75
# 4                                 2                                  2   77
#         time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0 2022-09-01     16.255476      11.298690               199.955952
# 1 2022-09-02     18.078810      12.598690               203.330952
# 2 2022-09-03     12.629405       8.825476               227.829762
# 3 2022-09-04     13.705476       9.491310               236.269048
# 4 2022-09-05     10.367381       7.225238               215.844048
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                  3.446071                 1.049405      73.120238
# 1                  2.840119                 1.064881      85.739286
# 2                  3.020952                 1.505952      88.171429
# 3                  3.076905                 1.189881      92.014286
# 4                  3.259762                 0.852381      82.526190
#
#    pm2_5 (μg/m³)_subindex  pm10 (μg/m³)_subindex  \
# 0                      19                     16
# 1                      21                     18
# 2                      15                     13
# 3                      16                     14
# 4                      12                     10
#
#    carbon_monoxide (μg/m³)_subindex  ozone (μg/m³)_subindex  \
# 0                                10                      73
# 1                                10                      86
# 2                                11                      88
# 3                                12                      92
# 4                                11                      83
#
#    sulphur_dioxide (μg/m³)_subindex  nitrogen_dioxide (μg/m³)_subindex  AQI
# 0                                 1                                  4   73
# 1                                 1                                  4   86
# 2                                 2                                  4   88
# 3                                 1                                  4   92
# 4                                 1                                  4   83
# AQI computed and saved for Mawlynnong
