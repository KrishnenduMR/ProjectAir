# %%
import os
import pandas as pd
import numpy as np
import sub_index
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = "../data/preprocessed/"
output_dir = "../data/AQIdata/"
os.makedirs(output_dir, exist_ok=True)

# %%
stations = ["Chennai", "Delhi", "Koonimedu","Mawlynnong"]

# %%
from sub_index import get_PM25_subindex, get_PM10_subindex, get_CO_subindex, get_O3_subindex, get_SO2_subindex, get_NOx_subindex

# %%
import os
import pandas as pd
import numpy as np

# Process each station separately
for station in stations:
    file_path = os.path.join(data_dir, f"{station}_preprocessed.csv")
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        continue

    # Load data
    df = pd.read_csv(file_path)

    print(f"\n==== {station.upper()} - RAW DATA HEAD ====")
    print(df.head())

    # Convert timestamp column
    df["time"] = pd.to_datetime(df["time"])
    df.set_index("time", inplace=True)  # Ensure Timestamp is the index

    # Convert all numeric columns to float
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')

    print(f"\n==== {station.upper()} - DATA INFO ====")
    print(df.info())

    # AQI Sub-Index Calculation
    df["PM2.5_SubIndex"] = df["pm2_5 (μg/m³)"].apply(lambda x: get_PM25_subindex(x))
    df["PM10_SubIndex"] = df["pm10 (μg/m³)"].apply(lambda x: get_PM10_subindex(x))
    df["CO_SubIndex"] = df["carbon_monoxide (μg/m³)"].apply(lambda x: get_CO_subindex(x/1000))
    df["Ozone_SubIndex"] = df["ozone (μg/m³)"].apply(lambda x: get_O3_subindex(x))
    df["SO2_SubIndex"] = df["sulphur_dioxide (μg/m³)"].apply(lambda x: get_SO2_subindex(x))
    df["NOx_SubIndex"] = df["nitrogen_dioxide (μg/m³)"].apply(lambda x: get_NOx_subindex(x))

    # Debug sub-index values
    print(f"\n==== {station.upper()} - SUB-INDEX STATISTICS ====")
    print(df[["PM2.5_SubIndex", "PM10_SubIndex", "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "NOx_SubIndex"]].describe())

    # AQI Calculation (Max Sub-Index Method)
    df["Checks"] = (df["PM2.5_SubIndex"] > 0).astype(int) + \
                   (df["PM10_SubIndex"] > 0).astype(int) + \
                   (df["NOx_SubIndex"] > 0).astype(int) + \
                   (df["CO_SubIndex"] > 0).astype(int) + \
                   (df["SO2_SubIndex"] > 0).astype(int) + \
                   (df["Ozone_SubIndex"] > 0).astype(int)

    df["AQI"] = df[["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                     "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex"]].max(axis=1)

    # Remove invalid AQI values (where less than 3 pollutants are available)
    df.loc[df["Checks"] < 3, "AQI"] = np.nan

    # Debug high AQI values
    print(f"\n⚠️ Debugging High AQI Values for {station} ⚠️")
    print(df[df["AQI"] > 500][["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                                "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "AQI"]])
    
    # Save hourly AQI data
    output_path = os.path.join(output_dir, f"{station}_hourly_aqi.csv")
    df.to_csv(output_path)
    print(f"✅ Saved hourly AQI data for {station}: {output_path}")

print("\n🎉 Processing complete!")
# Out:
# ==== CHENNAI - RAW DATA HEAD ====
#                   time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01 00:00:00          21.7           14.6                      305
# 1  2022-09-01 01:00:00          21.0           14.3                      291
# 2  2022-09-01 02:00:00          19.0           13.0                      272
# 3  2022-09-01 03:00:00          15.8           10.7                      245
# 4  2022-09-01 04:00:00          14.4            9.7                      227
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)     City
# 0                      25.4                     30.6             12  Chennai
# 1                      23.1                     30.0             15  Chennai
# 2                      19.9                     29.1             20  Chennai
# 3                      15.9                     27.8             25  Chennai
# 4                      13.9                     26.9             28  Chennai
#
# ==== CHENNAI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  int64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  int64
#  6   City                      0 non-null      float64
# dtypes: float64(5), int64(2)
# memory usage: 1.3 MB
# None
#
# ==== CHENNAI - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex PM10_SubIndex  \
# count                           21216         21216
# unique                            655           827
# top     27.66666666666666903514245253          28.5
# freq                              104            68
#
#                           CO_SubIndex Ozone_SubIndex SO2_SubIndex  \
# count                           21216          21216        21216
# unique                            691            224          714
# top     10.79999999999999987787546729             65            5
# freq                              142            269          204
#
#                          NOx_SubIndex
# count                           21216
# unique                            645
# top     5.374999999999999777955395075
# freq                              181
#
# ⚠️ Debugging High AQI Values for Chennai ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Chennai: ../data/AQIData/Chennai_hourly_aqi.csv
#
# ==== DELHI - RAW DATA HEAD ====
#                   time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01 00:00:00         108.5           68.9                     1220
# 1  2022-09-01 01:00:00          89.4           55.9                     1117
# 2  2022-09-01 02:00:00          82.9           51.9                      970
# 3  2022-09-01 03:00:00          72.4           41.8                      768
# 4  2022-09-01 04:00:00          68.0           36.9                      622
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)   City
# 0                      64.2                     37.0              3  Delhi
# 1                      59.5                     33.7             11  Delhi
# 2                      52.8                     28.9             22  Delhi
# 3                      42.7                     23.8             43  Delhi
# 4                      33.8                     22.8             67  Delhi
#
# ==== DELHI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  int64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  int64
#  6   City                      0 non-null      float64
# dtypes: float64(5), int64(2)
# memory usage: 1.3 MB
# None
#
# ==== DELHI - SUB-INDEX STATISTICS ====
#        PM2.5_SubIndex                  PM10_SubIndex  \
# count           21216                          21216
# unique           1053                           1159
# top             105.0  117.1333333333333352281139620
# freq               69                             69
#
#                           CO_SubIndex Ozone_SubIndex SO2_SubIndex NOx_SubIndex
# count                           21216          21216        21216        21216
# unique                           3469            309         1685         1643
# top     18.49999999999999977795539507              0       28.125            0
# freq                               37            513           73           60
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  int64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  int64
#  6   City                      0 non-null      float64
# dtypes: float64(5), int64(2)
# memory usage: 1.3 MB
# None
#
# ==== KOONIMEDU - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                            632                            803
# top     26.99999999999999881576210707  26.80000000000000071054273576
# freq                              121                             95
#
#                           CO_SubIndex Ozone_SubIndex  \
# count                           21216          21216
# unique                            453            216
# top     9.450000000000000066613381478             69
# freq                              179            309
#
#                           SO2_SubIndex NOx_SubIndex
# count                            21216        21216
# unique                             531          558
# top     0.5000000000000000277555756158        1.875
# freq                               614          400
#
# ⚠️ Debugging High AQI Values for Koonimedu ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Koonimedu: ../data/AQIData/Koonimedu_hourly_aqi.csv
#
# ==== MAWLYNNONG - RAW DATA HEAD ====
#                   time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01 00:00:00          19.3           13.4                      219
# 1  2022-09-01 01:00:00          16.2           11.3                      212
# 2  2022-09-01 02:00:00          13.2            9.2                      201
# 3  2022-09-01 03:00:00          12.8            8.8                      188
# 4  2022-09-01 04:00:00          13.2            9.1                      180
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                       2.2                      1.5             75
# 1                       2.2                      1.6             75
# 2                       2.3                      1.8             74
# 3                       2.2                      1.9             75
# 4                       2.0                      1.6             77
#
#          City
# 0  Mawlynnong
# 1  Mawlynnong
# 2  Mawlynnong
# 3  Mawlynnong
# 4  Mawlynnong
#
# ==== MAWLYNNONG - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  int64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  int64
#  6   City                      0 non-null      float64
# dtypes: float64(5), int64(2)
# memory usage: 1.3 MB
# None
#
# ==== MAWLYNNONG - SUB-INDEX STATISTICS ====
#                       PM2.5_SubIndex                  PM10_SubIndex  \
# count                          21216                          21216
# unique                           654                            783
# top     17.3333333333333339254522798  15.30000000000000071054273576
# freq                             131                             90
#
#                           CO_SubIndex Ozone_SubIndex  \
# count                           21216          21216
# unique                            703            176
# top     12.60000000000000008881784197             74
# freq                              116            271
#
#                          SO2_SubIndex                   NOx_SubIndex
# count                           21216                          21216
# unique                            174                            253
# top     1.125000000000000027755575616  1.125000000000000027755575616
# freq                              745                            561
#
# ⚠️ Debugging High AQI Values for Mawlynnong ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Mawlynnong: ../data/AQIData/Mawlynnong_hourly_aqi.csv
#
# 🎉 Processing complete!
