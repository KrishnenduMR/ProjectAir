# %%
import os
import pandas as pd
import numpy as np
import sub_index
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = "../data/preprocessed/"
output_dir = "../data/AQIdata/"
os.makedirs(output_dir, exist_ok=True)

# %%
stations = ["Chennai", "Delhi", "Koonimedu","Mawlynnong"]

# %%
from sub_index import get_PM25_subindex, get_PM10_subindex, get_CO_subindex, get_O3_subindex, get_SO2_subindex, get_NOx_subindex

# %%
import os
import pandas as pd
import numpy as np

# Process each station separately
for station in stations:
    file_path = f"..//data/cleaneddata/{station}.csv"
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        continue

    # Load data
    df = pd.read_csv(file_path)

    print(f"\n==== {station.upper()} - RAW DATA HEAD ====")
    print(df.head())

    # Convert timestamp column
    df["time"] = pd.to_datetime(df["time"])
    df.set_index("time", inplace=True)  # Ensure Timestamp is the index

    # Convert all numeric columns to float
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')

    print(f"\n==== {station.upper()} - DATA INFO ====")
    print(df.info())

    # AQI Sub-Index Calculation
    df["PM2.5_SubIndex"] = df["pm2_5 (μg/m³)"].apply(lambda x: get_PM25_subindex(x))
    df["PM10_SubIndex"] = df["pm10 (μg/m³)"].apply(lambda x: get_PM10_subindex(x))
    df["CO_SubIndex"] = df["carbon_monoxide (μg/m³)"].apply(lambda x: get_CO_subindex(x/1000))
    df["Ozone_SubIndex"] = df["ozone (μg/m³)"].apply(lambda x: get_O3_subindex(x))
    df["SO2_SubIndex"] = df["sulphur_dioxide (μg/m³)"].apply(lambda x: get_SO2_subindex(x))
    df["NOx_SubIndex"] = df["nitrogen_dioxide (μg/m³)"].apply(lambda x: get_NOx_subindex(x))

    # Debug sub-index values
    print(f"\n==== {station.upper()} - SUB-INDEX STATISTICS ====")
    print(df[["PM2.5_SubIndex", "PM10_SubIndex", "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "NOx_SubIndex"]].describe())

    # AQI Calculation (Max Sub-Index Method)
    df["Checks"] = (df["PM2.5_SubIndex"] > 0).astype(int) + \
                   (df["PM10_SubIndex"] > 0).astype(int) + \
                   (df["NOx_SubIndex"] > 0).astype(int) + \
                   (df["CO_SubIndex"] > 0).astype(int) + \
                   (df["SO2_SubIndex"] > 0).astype(int) + \
                   (df["Ozone_SubIndex"] > 0).astype(int)

    df["AQI"] = df[["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                     "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex"]].max(axis=1)

    # Remove invalid AQI values (where less than 3 pollutants are available)
    df.loc[df["Checks"] < 3, "AQI"] = np.nan

    # Debug high AQI values
    print(f"\n⚠️ Debugging High AQI Values for {station} ⚠️")
    print(df[df["AQI"] > 500][["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                                "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "AQI"]])
    
    # Save hourly AQI data
    output_path = os.path.join(output_dir, f"{station}_hourly_aqi.csv")
    df.to_csv(output_path)
    print(f"✅ Saved hourly AQI data for {station}: {output_path}")

print("\n🎉 Processing complete!")
# Out:
# ==== CHENNAI - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     21.691429      14.634286               303.028571
# 1  2022-09-01T01:00     20.940000      14.240000               292.028571
# 2  2022-09-01T02:00     18.751429      12.802857               270.285714
# 3  2022-09-01T03:00     15.928571      10.820000               247.228571
# 4  2022-09-01T04:00     14.751429       9.914286               226.571429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 25.082857                30.522857      12.342857
# 1                 23.211429                30.034286      15.085714
# 2                 19.668571                29.022857      20.000000
# 3                 16.268571                27.911429      24.742857
# 4                 13.840000                26.925714      27.914286
#
# ==== CHENNAI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== CHENNAI - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          14025                          16201
# top     25.99999999999998460490739186  1.199999999999999289457264240
# freq                                8                             11
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                          10780                           5594
# top     2.949999999999998109845300576  74.08571428571424632991693216
# freq                               21                             30
#
#                          SO2_SubIndex NOx_SubIndex
# count                           21216        21216
# unique                          10540        10964
# top     4.114285714285711437199211105            0
# freq                               26           56
#
# ⚠️ Debugging High AQI Values for Chennai ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Chennai: ../data/AQIdata/Chennai_hourly_aqi.csv
#
# ==== DELHI - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00    104.145714      65.900000              1206.114286
# 1  2022-09-01T01:00     93.540000      59.080000              1123.000000
# 2  2022-09-01T02:00     80.611429      49.637143               959.542857
# 3  2022-09-01T03:00     73.788571      43.137143               782.571429
# 4  2022-09-01T04:00     67.220000      36.428571               616.771429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 63.565714                36.562857       4.114286
# 1                 59.851429                33.751429       9.971429
# 2                 52.285714                28.625714      23.200000
# 3                 43.274286                24.425714      42.142857
# 4                 33.542857                22.671429      67.771429
#
# ==== DELHI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== DELHI - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          18285                          19341
# top     150.4444444444443244416712938  156.0666666666665870858802615
# freq                               20                             20
#
#                           CO_SubIndex Ozone_SubIndex  \
# count                           21216          21216
# unique                          18895           9569
# top     102.6749999999999884980894649              0
# freq                               20            147
#
#                         SO2_SubIndex NOx_SubIndex
# count                          21216        21216
# unique                         16369        18041
# top     87.1666666666666145601993776            0
# freq                              20           56
#
# ⚠️ Debugging High AQI Values for Delhi ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Delhi: ../data/AQIdata/Delhi_hourly_aqi.csv
#
# ==== KOONIMEDU - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     27.040000      18.380000               208.657143
# 1  2022-09-01T01:00     27.017143      18.394286               206.342857
# 2  2022-09-01T02:00     26.025714      17.717143               200.657143
# 3  2022-09-01T03:00     23.960000      16.242857               191.000000
# 4  2022-09-01T04:00     21.588571      14.522857               177.000000
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 12.143810                19.897143      11.600000
# 1                 12.382857                19.112381      14.657143
# 2                 11.256190                16.813333      20.514286
# 3                 12.682857                16.433333      26.228571
# 4                 14.131429                19.480000      31.514286
#
# ==== KOONIMEDU - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== KOONIMEDU - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          13398                          15770
# top     18.36190476190475114511476325  25.80285714285712828086616354
# freq                               10                              6
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                           9026                           5581
# top     9.458571428571424521969390753  67.99999999999995736743585439
# freq                               19                             45
#
#                           SO2_SubIndex NOx_SubIndex
# count                            21216        21216
# unique                            9278         7829
# top     0.4999999999999996114219413812            0
# freq                               157           56
#
# ⚠️ Debugging High AQI Values for Koonimedu ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Koonimedu: ../data/AQIdata/Koonimedu_hourly_aqi.csv
#
# ==== MAWLYNNONG - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     18.760000      13.040000               218.142857
# 1  2022-09-01T01:00     16.260000      11.334286               212.085714
# 2  2022-09-01T02:00     13.568571       9.431429               200.571429
# 3  2022-09-01T03:00     12.757143       8.800000               188.942857
# 4  2022-09-01T04:00     13.080000       9.014286               179.485714
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                  2.191429                 1.508571      75.085714
# 1                  2.234286                 1.617143      74.657143
# 2                  2.265714                 1.808571      74.342857
# 3                  2.208571                 1.848571      75.000000
# 4                  1.982857                 1.608571      76.828571
#
# ==== MAWLYNNONG - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== MAWLYNNONG - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                   PM10_SubIndex  \
# count                           21216                           21216
# unique                          14255                           15948
# top     1.166666666666665852503115275  0.9999999999999994448884876874
# freq                               18                               9
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                          11382                           5512
# top     11.04571428571427954556938289  51.91428571428568261580949184
# freq                               12                             27
#
#                          SO2_SubIndex NOx_SubIndex
# count                           21216        21216
# unique                           4295         7057
# top     1.124999999999999333866185225            0
# freq                               98           56
#
# ⚠️ Debugging High AQI Values for Mawlynnong ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved hourly AQI data for Mawlynnong: ../data/AQIdata/Mawlynnong_hourly_aqi.csv
#
# 🎉 Processing complete!

# %%
import os
import pandas as pd
import numpy as np

# Process each station separately
for station in stations:
    file_path = f"..//data/cleaneddata/{station}.csv"
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        continue

    # Load data
    df = pd.read_csv(file_path)

    print(f"\n==== {station.upper()} - RAW DATA HEAD ====")
    print(df.head())

    # Convert timestamp column
    df["time"] = pd.to_datetime(df["time"])
    df.set_index("time", inplace=True)  # Ensure Timestamp is the index

    # Convert all numeric columns to float
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')

    print(f"\n==== {station.upper()} - DATA INFO ====")
    print(df.info())

    # AQI Sub-Index Calculation
    df["PM2.5_SubIndex"] = df["pm2_5 (μg/m³)"].apply(lambda x: get_PM25_subindex(x))
    df["PM10_SubIndex"] = df["pm10 (μg/m³)"].apply(lambda x: get_PM10_subindex(x))
    df["CO_SubIndex"] = df["carbon_monoxide (μg/m³)"].apply(lambda x: get_CO_subindex(x/1000))
    df["Ozone_SubIndex"] = df["ozone (μg/m³)"].apply(lambda x: get_O3_subindex(x))
    df["SO2_SubIndex"] = df["sulphur_dioxide (μg/m³)"].apply(lambda x: get_SO2_subindex(x))
    df["NOx_SubIndex"] = df["nitrogen_dioxide (μg/m³)"].apply(lambda x: get_NOx_subindex(x))

    # Debug sub-index values
    print(f"\n==== {station.upper()} - SUB-INDEX STATISTICS ====")
    print(df[["PM2.5_SubIndex", "PM10_SubIndex", "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "NOx_SubIndex"]].describe())

    # Compute Daily Maximum Sub-Index (Max Sub-Index Method)
    daily_df = df.resample("D").max()

    daily_df["Checks"] = (daily_df["PM2.5_SubIndex"] > 0).astype(int) + \
                         (daily_df["PM10_SubIndex"] > 0).astype(int) + \
                         (daily_df["NOx_SubIndex"] > 0).astype(int) + \
                         (daily_df["CO_SubIndex"] > 0).astype(int) + \
                         (daily_df["SO2_SubIndex"] > 0).astype(int) + \
                         (daily_df["Ozone_SubIndex"] > 0).astype(int)

    daily_df["AQI"] = daily_df[["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                                "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex"]].max(axis=1)

    # Remove invalid AQI values (where less than 3 pollutants are available)
    daily_df.loc[daily_df["Checks"] < 3, "AQI"] = np.nan

    # Debug high AQI values
    print(f"\n⚠️ Debugging High AQI Values for {station} ⚠️")
    print(daily_df[daily_df["AQI"] > 500][["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", 
                                            "CO_SubIndex", "Ozone_SubIndex", "SO2_SubIndex", "AQI"]])

    # Save daily AQI data
    output_path = os.path.join(output_dir, f"{station}_daily_aqi.csv")
    daily_df.to_csv(output_path)
    print(f"✅ Saved daily AQI data for {station}: {output_path}")

print("\n🎉 Daily AQI processing complete!")
# Out:
# ==== CHENNAI - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     21.691429      14.634286               303.028571
# 1  2022-09-01T01:00     20.940000      14.240000               292.028571
# 2  2022-09-01T02:00     18.751429      12.802857               270.285714
# 3  2022-09-01T03:00     15.928571      10.820000               247.228571
# 4  2022-09-01T04:00     14.751429       9.914286               226.571429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 25.082857                30.522857      12.342857
# 1                 23.211429                30.034286      15.085714
# 2                 19.668571                29.022857      20.000000
# 3                 16.268571                27.911429      24.742857
# 4                 13.840000                26.925714      27.914286
#
# ==== CHENNAI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== CHENNAI - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          14025                          16201
# top     25.99999999999998460490739186  1.199999999999999289457264240
# freq                                8                             11
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                          10780                           5594
# top     2.949999999999998109845300576  74.08571428571424632991693216
# freq                               21                             30
#
#                          SO2_SubIndex NOx_SubIndex
# count                           21216        21216
# unique                          10540        10964
# top     4.114285714285711437199211105            0
# freq                               26           56
#
# ⚠️ Debugging High AQI Values for Chennai ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved daily AQI data for Chennai: ../data/AQIdata/Chennai_daily_aqi.csv
#
# ==== DELHI - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00    104.145714      65.900000              1206.114286
# 1  2022-09-01T01:00     93.540000      59.080000              1123.000000
# 2  2022-09-01T02:00     80.611429      49.637143               959.542857
# 3  2022-09-01T03:00     73.788571      43.137143               782.571429
# 4  2022-09-01T04:00     67.220000      36.428571               616.771429
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 63.565714                36.562857       4.114286
# 1                 59.851429                33.751429       9.971429
# 2                 52.285714                28.625714      23.200000
# 3                 43.274286                24.425714      42.142857
# 4                 33.542857                22.671429      67.771429
#
# ==== DELHI - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== DELHI - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          18285                          19341
# top     150.4444444444443244416712938  156.0666666666665870858802615
# freq                               20                             20
#
#                           CO_SubIndex Ozone_SubIndex  \
# count                           21216          21216
# unique                          18895           9569
# top     102.6749999999999884980894649              0
# freq                               20            147
#
#                         SO2_SubIndex NOx_SubIndex
# count                          21216        21216
# unique                         16369        18041
# top     87.1666666666666145601993776            0
# freq                              20           56
#
# ⚠️ Debugging High AQI Values for Delhi ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved daily AQI data for Delhi: ../data/AQIdata/Delhi_daily_aqi.csv
#
# ==== KOONIMEDU - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     27.040000      18.380000               208.657143
# 1  2022-09-01T01:00     27.017143      18.394286               206.342857
# 2  2022-09-01T02:00     26.025714      17.717143               200.657143
# 3  2022-09-01T03:00     23.960000      16.242857               191.000000
# 4  2022-09-01T04:00     21.588571      14.522857               177.000000
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                 12.143810                19.897143      11.600000
# 1                 12.382857                19.112381      14.657143
# 2                 11.256190                16.813333      20.514286
# 3                 12.682857                16.433333      26.228571
# 4                 14.131429                19.480000      31.514286
#
# ==== KOONIMEDU - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== KOONIMEDU - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                  PM10_SubIndex  \
# count                           21216                          21216
# unique                          13398                          15770
# top     18.36190476190475114511476325  25.80285714285712828086616354
# freq                               10                              6
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                           9026                           5581
# top     9.458571428571424521969390753  67.99999999999995736743585439
# freq                               19                             45
#
#                           SO2_SubIndex NOx_SubIndex
# count                            21216        21216
# unique                            9278         7829
# top     0.4999999999999996114219413812            0
# freq                               157           56
#
# ⚠️ Debugging High AQI Values for Koonimedu ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved daily AQI data for Koonimedu: ../data/AQIdata/Koonimedu_daily_aqi.csv
#
# ==== MAWLYNNONG - RAW DATA HEAD ====
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-09-01T00:00     18.760000      13.040000               218.142857
# 1  2022-09-01T01:00     16.260000      11.334286               212.085714
# 2  2022-09-01T02:00     13.568571       9.431429               200.571429
# 3  2022-09-01T03:00     12.757143       8.800000               188.942857
# 4  2022-09-01T04:00     13.080000       9.014286               179.485714
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)
# 0                  2.191429                 1.508571      75.085714
# 1                  2.234286                 1.617143      74.657143
# 2                  2.265714                 1.808571      74.342857
# 3                  2.208571                 1.848571      75.000000
# 4                  1.982857                 1.608571      76.828571
#
# ==== MAWLYNNONG - DATA INFO ====
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21216 entries, 2022-09-01 00:00:00 to 2025-01-31 23:00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pm10 (μg/m³)              21216 non-null  float64
#  1   pm2_5 (μg/m³)             21216 non-null  float64
#  2   carbon_monoxide (μg/m³)   21216 non-null  float64
#  3   nitrogen_dioxide (μg/m³)  21216 non-null  float64
#  4   sulphur_dioxide (μg/m³)   21216 non-null  float64
#  5   ozone (μg/m³)             21216 non-null  float64
# dtypes: float64(6)
# memory usage: 1.1 MB
# None
#
# ==== MAWLYNNONG - SUB-INDEX STATISTICS ====
#                        PM2.5_SubIndex                   PM10_SubIndex  \
# count                           21216                           21216
# unique                          14255                           15948
# top     1.166666666666665852503115275  0.9999999999999994448884876874
# freq                               18                               9
#
#                           CO_SubIndex                 Ozone_SubIndex  \
# count                           21216                          21216
# unique                          11382                           5512
# top     11.04571428571427954556938289  51.91428571428568261580949184
# freq                               12                             27
#
#                          SO2_SubIndex NOx_SubIndex
# count                           21216        21216
# unique                           4295         7057
# top     1.124999999999999333866185225            0
# freq                               98           56
#
# ⚠️ Debugging High AQI Values for Mawlynnong ⚠️
# Empty DataFrame
# Columns: [PM2.5_SubIndex, PM10_SubIndex, NOx_SubIndex, CO_SubIndex, Ozone_SubIndex, SO2_SubIndex, AQI]
# Index: []
# ✅ Saved daily AQI data for Mawlynnong: ../data/AQIdata/Mawlynnong_daily_aqi.csv
#
# 🎉 Daily AQI processing complete!
